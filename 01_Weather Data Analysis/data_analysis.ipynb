# %% [markdown]
# # Weather Dataset Analysis
#
# This notebook analyzes time-series weather data containing per-hour information about:
# - Temperature
# - Dew Point Temperature
# - Relative Humidity
# - Wind Speed
# - Visibility
# - Pressure
# - Weather Conditions
#
# The analysis will explore various aspects of the dataset using Pandas.

# %%
import pandas as pd

# Load the dataset with proper error handling
try:
    weather_df = pd.read_csv("Weather Dataset.csv")
    print("Dataset loaded successfully")
except FileNotFoundError:
    print("Error: File not found. Please check the file path.")
except Exception as e:
    print(f"An error occurred while loading the dataset: {str(e)}")
# Out:
# Dataset loaded successfully

# %% [markdown]
# ## Initial Data Exploration
# Let's examine the basic structure and characteristics of our dataset.

# %%
print("\n=== First 5 Rows ===")
display(weather_df.head())
# Out:
# === First 5 Rows ===
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
print("\n=== DataFrame Shape ===")
print(f"Rows: {weather_df.shape[0]}, Columns: {weather_df.shape[1]}")
# Out:
# === DataFrame Shape ===
# Rows: 8784, Columns: 8

# %%
print("\n=== Column Information ===")
print(weather_df.columns.tolist())
# Out:
# === Column Information ===
# ['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather']

# %%
print("\n=== Data Types ===")
print(weather_df.dtypes)
# Out:
# === Data Types ===
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
print("\n=== Basic Statistics ===")
display(weather_df.describe(include='all'))
# Out:
# === Basic Statistics ===
#             Date/Time       Temp_C  Dew Point Temp_C    Rel Hum_%  \
# count            8784  8784.000000       8784.000000  8784.000000
# unique           8784          NaN               NaN          NaN
# top     1/1/2012 0:00          NaN               NaN          NaN
# freq                1          NaN               NaN          NaN
# mean              NaN     8.798144          2.555294    67.431694
# std               NaN    11.687883         10.883072    16.918881
# min               NaN   -23.300000        -28.500000    18.000000
# 25%               NaN     0.100000         -5.900000    56.000000
# 50%               NaN     9.300000          3.300000    68.000000
# 75%               NaN    18.800000         11.800000    81.000000
# max               NaN    33.000000         24.400000   100.000000
#
#         Wind Speed_km/h  Visibility_km    Press_kPa       Weather
# count       8784.000000    8784.000000  8784.000000          8784
# unique              NaN            NaN          NaN            50
# top                 NaN            NaN          NaN  Mainly Clear
# freq                NaN            NaN          NaN          2106
# mean          14.945469      27.664447   101.051623           NaN
# std            8.688696      12.622688     0.844005           NaN
# min            0.000000       0.200000    97.520000           NaN
# 25%            9.000000      24.100000   100.560000           NaN
# 50%           13.000000      25.000000   101.070000           NaN
# 75%           20.000000      25.000000   101.590000           NaN
# max           83.000000      48.300000   103.650000           NaN

# %%
print("\n=== Missing Values Summary ===")
print(weather_df.isnull().sum())
# Out:
# === Missing Values Summary ===
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
# Rename columns for consistency
weather_df.rename(columns={
    'Weather': 'Weather_Condition',
    'Wind Speed_km/h': 'Wind_Speed_kmh',
    'Visibility_km': 'Visibility_km',
    'Press_kPa': 'Pressure_kPa',
    'Rel Hum_%': 'Relative_Humidity_pct'
}, inplace=True)

# %%
# Verify changes
print("Updated columns:", weather_df.columns.tolist())
# Out:
# Updated columns: ['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Relative_Humidity_pct', 'Wind_Speed_kmh', 'Visibility_km', 'Pressure_kPa', 'Weather_Condition']

# %% [markdown]
# ## Analysis Questions

# %%
# Q1: Unique wind speeds
unique_wind_speeds = weather_df['Wind_Speed_kmh'].unique()
print("\n1. Unique wind speeds:", sorted(unique_wind_speeds))
# Out:
# 1. Unique wind speeds: [0, 2, 4, 6, 7, 9, 11, 13, 15, 17, 19, 20, 22, 24, 26, 28, 30, 32, 33, 35, 37, 39, 41, 43, 44, 46, 48, 50, 52, 54, 57, 63, 70, 83]

# %%
# Q2: Count of clear weather conditions
clear_weather_count = weather_df[weather_df['Weather_Condition'] == 'Clear'].shape[0]
print(f"\n2. Clear weather occurrences: {clear_weather_count}")
# Out:
# 2. Clear weather occurrences: 1326

# %%
# Q3: Wind speed exactly 4 km/h
wind_speed_4_count = weather_df[weather_df['Wind_Speed_kmh'] == 4].shape[0]
print(f"\n3. Wind speed = 4 km/h occurrences: {wind_speed_4_count}")
    
# Q4: Null values check (already shown in basic info)
# Out:
# 3. Wind speed = 4 km/h occurrences: 474

# %%
# Q6-8: Statistical measures
print("\n6. Mean Visibility:", weather_df['Visibility_km'].mean())
print("7. Pressure Standard Deviation:", weather_df['Pressure_kPa'].std())
print("8. Relative Humidity Variance:", weather_df['Relative_Humidity_pct'].var())
# Out:
# 6. Mean Visibility: 27.664446721311478
# 7. Pressure Standard Deviation: 0.8440047459486474
# 8. Relative Humidity Variance: 286.2485501984998

# %%
# Q9: Snow records
snow_records = weather_df[weather_df['Weather_Condition'].str.contains('Snow', case=False, na=False)]
print(f"\n9. Snow records found: {snow_records.shape[0]}")
# Out:
# 9. Snow records found: 583

# %%
# Q10: High wind speed and good visibility
high_wind_good_vis = weather_df[(weather_df['Wind_Speed_kmh'] > 24) & 
                           (weather_df['Visibility_km'] == 25)]
print("\n10. Records with wind >24 km/h and visibility 25 km:")
display(high_wind_good_vis)
# Out:
# 10. Records with wind >24 km/h and visibility 25 km:
#              Date/Time  Temp_C  Dew Point Temp_C  Relative_Humidity_pct  \
# 23      1/1/2012 23:00     5.3               2.0                     79
# 24       1/2/2012 0:00     5.2               1.5                     77
# 25       1/2/2012 1:00     4.6               0.0                     72
# 26       1/2/2012 2:00     3.9              -0.9                     71
# 27       1/2/2012 3:00     3.7              -1.5                     69
# ...                ...     ...               ...                    ...
# 8705  12/28/2012 17:00    -8.6             -12.0                     76
# 8753  12/30/2012 17:00   -12.1             -15.8                     74
# 8755  12/30/2012 19:00   -13.4             -16.5                     77
# 8759  12/30/2012 23:00   -12.1             -15.1                     78
# 8760   12/31/2012 0:00   -11.1             -14.4                     77
#
#       Wind_Speed_kmh  Visibility_km  Pressure_kPa Weather_Condition
# 23                30           25.0         99.31            Cloudy
# 24                35           25.0         99.26      Rain Showers
# 25                39           25.0         99.26            Cloudy
# 26                32           25.0         99.26     Mostly Cloudy
# 27                33           25.0         99.30     Mostly Cloudy
# ...              ...            ...           ...               ...
# 8705              26           25.0        101.34      Mainly Clear
# 8753              28           25.0        101.26      Mainly Clear
# 8755              26           25.0        101.47      Mainly Clear
# 8759              28           25.0        101.52     Mostly Cloudy
# 8760              26           25.0        101.51            Cloudy
#
# [308 rows x 8 columns]

# %%
# Q11: Mean by weather condition
print("\n11. Mean values by weather condition:")
display(weather_df.groupby('Weather_Condition').mean(numeric_only=True))
# Out:
# 11. Mean values by weather condition:
#                                             Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# Freezing Fog                             -7.575000         -9.250000
# Freezing Rain                            -3.885714         -6.078571
# Freezing Rain,Fog                        -2.225000         -3.750000
# Freezing Rain,Haze                       -4.900000         -7.450000
# Freezing Rain,Ice Pellets,Fog            -2.600000         -3.700000
# Freezing Rain,Snow Grains                -5.000000         -7.300000
# Haze                                     -0.200000         -2.975000
# Mainly Clear                             12.558927          4.581671
# Moderate Rain,Fog                         1.700000          0.800000
# Moderate Snow                            -5.525000         -7.250000
# Moderate Snow,Blowing Snow               -5.450000         -6.500000
# Mostly Cloudy                            10.574287          3.131174
# Rain                                      9.786275          7.042810
# Rain Showers                             13.722340          9.187766
# Rain Showers,Fog                         12.800000         12.100000
# Rain Showers,Snow Showers                 2.150000         -1.500000
# Rain,Fog                                  8.273276          7.219828
# Rain,Haze                                 4.633333          2.066667
# Rain,Ice Pellets                          0.600000         -0.600000
# Rain,Snow                                 1.055556         -0.566667
# Rain,Snow Grains                          1.900000         -2.100000
# Rain,Snow,Fog                             0.800000          0.300000
# Rain,Snow,Ice Pellets                     1.100000         -0.175000
# Snow                                     -4.524103         -7.623333
# Snow Pellets                              0.700000         -6.400000
# Snow Showers                             -3.506667         -7.866667
# Snow Showers,Fog                        -10.675000        -11.900000
# Snow,Blowing Snow                        -5.410526         -7.621053
# Snow,Fog                                 -5.075676         -6.364865
# Snow,Haze                                -4.020000         -6.860000
# Snow,Ice Pellets                         -1.883333         -3.666667
# Thunderstorms                            24.150000         19.750000
# Thunderstorms,Heavy Rain Showers         10.900000          9.000000
# Thunderstorms,Moderate Rain Showers,Fog  19.600000         18.500000
# Thunderstorms,Rain                       20.433333         18.533333
# Thunderstorms,Rain Showers               20.037500         17.618750
# Thunderstorms,Rain Showers,Fog           21.600000         18.700000
# Thunderstorms,Rain,Fog                   20.600000         18.600000
#
#                                          Relative_Humidity_pct  \
# Weather_Condition
# Clear                                                64.497738
# Cloudy                                               69.592593
# Drizzle                                              88.243902
# Drizzle,Fog                                          93.275000
# Drizzle,Ice Pellets,Fog                              92.000000
# Drizzle,Snow                                         93.500000
# Drizzle,Snow,Fog                                     95.866667
# Fog                                                  92.286667
# Freezing Drizzle                                     83.571429
# Freezing Drizzle,Fog                                 88.500000
# Freezing Drizzle,Haze                                82.000000
# Freezing Drizzle,Snow                                86.090909
# Freezing Fog                                         87.750000
# Freezing Rain                                        84.642857
# Freezing Rain,Fog                                    89.500000
# Freezing Rain,Haze                                   82.500000
# Freezing Rain,Ice Pellets,Fog                        92.000000
# Freezing Rain,Snow Grains                            84.000000
# Haze                                                 81.625000
# Mainly Clear                                         60.667142
# Moderate Rain,Fog                                    94.000000
# Moderate Snow                                        87.750000
# Moderate Snow,Blowing Snow                           92.500000
# Mostly Cloudy                                        62.102465
# Rain                                                 83.624183
# Rain Showers                                         75.159574
# Rain Showers,Fog                                     96.000000
# Rain Showers,Snow Showers                            76.500000
# Rain,Fog                                             93.189655
# Rain,Haze                                            83.333333
# Rain,Ice Pellets                                     92.000000
# Rain,Snow                                            89.000000
# Rain,Snow Grains                                     75.000000
# Rain,Snow,Fog                                        96.000000
# Rain,Snow,Ice Pellets                                91.500000
# Snow                                                 79.307692
# Snow Pellets                                         59.000000
# Snow Showers                                         72.350000
# Snow Showers,Fog                                     90.750000
# Snow,Blowing Snow                                    84.473684
# Snow,Fog                                             90.675676
# Snow,Haze                                            80.600000
# Snow,Ice Pellets                                     87.666667
# Thunderstorms                                        77.000000
# Thunderstorms,Heavy Rain Showers                     88.000000
# Thunderstorms,Moderate Rain Showers,Fog              93.000000
# Thunderstorms,Rain                                   89.000000
# Thunderstorms,Rain Showers                           86.375000
# Thunderstorms,Rain Showers,Fog                       84.000000
# Thunderstorms,Rain,Fog                               88.000000
#
#                                          Wind_Speed_kmh  Visibility_km  \
# Weather_Condition
# Clear                                         10.557315      30.153243
# Cloudy                                        16.127315      26.625752
# Drizzle                                       16.097561      17.931707
# Drizzle,Fog                                   11.862500       5.257500
# Drizzle,Ice Pellets,Fog                       20.000000       4.000000
# Drizzle,Snow                                  14.000000      10.500000
# Drizzle,Snow,Fog                              15.533333       5.513333
# Fog                                            7.946667       6.248000
# Freezing Drizzle                              16.571429       9.200000
# Freezing Drizzle,Fog                          17.000000       5.266667
# Freezing Drizzle,Haze                         10.333333       2.666667
# Freezing Drizzle,Snow                         16.272727       5.872727
# Freezing Fog                                   4.750000       0.650000
# Freezing Rain                                 19.214286       8.242857
# Freezing Rain,Fog                             15.500000       7.550000
# Freezing Rain,Haze                             7.500000       2.400000
# Freezing Rain,Ice Pellets,Fog                 28.000000       8.000000
# Freezing Rain,Snow Grains                     32.000000       4.800000
# Haze                                          10.437500       7.831250
# Mainly Clear                                  14.144824      34.264862
# Moderate Rain,Fog                             17.000000       6.400000
# Moderate Snow                                 33.750000       0.750000
# Moderate Snow,Blowing Snow                    40.000000       0.600000
# Mostly Cloudy                                 15.813920      31.253842
# Rain                                          19.254902      18.856536
# Rain Showers                                  17.132979      22.816489
# Rain Showers,Fog                              13.000000       6.400000
# Rain Showers,Snow Showers                     22.500000      21.700000
# Rain,Fog                                      14.793103       6.873276
# Rain,Haze                                     11.666667       6.700000
# Rain,Ice Pellets                              24.000000       9.700000
# Rain,Snow                                     28.388889      11.672222
# Rain,Snow Grains                              26.000000      25.000000
# Rain,Snow,Fog                                  9.000000       6.400000
# Rain,Snow,Ice Pellets                         23.250000       6.000000
# Snow                                          20.038462      11.171795
# Snow Pellets                                  35.000000       2.400000
# Snow Showers                                  19.233333      20.158333
# Snow Showers,Fog                              13.750000       7.025000
# Snow,Blowing Snow                             34.842105       4.105263
# Snow,Fog                                      17.324324       4.537838
# Snow,Haze                                      5.000000       4.640000
# Snow,Ice Pellets                              23.833333       7.416667
# Thunderstorms                                  7.500000      24.550000
# Thunderstorms,Heavy Rain Showers               9.000000       2.400000
# Thunderstorms,Moderate Rain Showers,Fog       15.000000       3.200000
# Thunderstorms,Rain                            15.666667      19.833333
# Thunderstorms,Rain Showers                    18.312500      15.893750
# Thunderstorms,Rain Showers,Fog                19.666667       9.700000
# Thunderstorms,Rain,Fog                        19.000000       4.800000
#
#                                          Pressure_kPa
# Weather_Condition
# Clear                                      101.587443
# Cloudy                                     100.911441
# Drizzle                                    100.435366
# Drizzle,Fog                                100.786625
# Drizzle,Ice Pellets,Fog                    100.790000
# Drizzle,Snow                               100.890000
# Drizzle,Snow,Fog                            99.281333
# Fog                                        101.184067
# Freezing Drizzle                           100.202857
# Freezing Drizzle,Fog                       100.441667
# Freezing Drizzle,Haze                      100.316667
# Freezing Drizzle,Snow                      100.520909
# Freezing Fog                               102.320000
# Freezing Rain                               99.647143
# Freezing Rain,Fog                           99.945000
# Freezing Rain,Haze                         100.375000
# Freezing Rain,Ice Pellets,Fog              100.950000
# Freezing Rain,Snow Grains                   98.560000
# Haze                                       101.482500
# Mainly Clear                               101.248832
# Moderate Rain,Fog                           99.980000
# Moderate Snow                              100.275000
# Moderate Snow,Blowing Snow                 100.570000
# Mostly Cloudy                              101.025288
# Rain                                       100.233333
# Rain Showers                               100.404043
# Rain Showers,Fog                            99.830000
# Rain Showers,Snow Showers                  101.100000
# Rain,Fog                                   100.500862
# Rain,Haze                                  100.540000
# Rain,Ice Pellets                           100.120000
# Rain,Snow                                   99.951111
# Rain,Snow Grains                           100.600000
# Rain,Snow,Fog                              100.730000
# Rain,Snow,Ice Pellets                      100.105000
# Snow                                       100.536103
# Snow Pellets                                99.700000
# Snow Showers                               100.963500
# Snow Showers,Fog                           101.292500
# Snow,Blowing Snow                           99.704737
# Snow,Fog                                   100.688649
# Snow,Haze                                  100.782000
# Snow,Ice Pellets                           100.548333
# Thunderstorms                              100.230000
# Thunderstorms,Heavy Rain Showers           100.260000
# Thunderstorms,Moderate Rain Showers,Fog    100.010000
# Thunderstorms,Rain                         100.420000
# Thunderstorms,Rain Showers                 100.233750
# Thunderstorms,Rain Showers,Fog             100.063333
# Thunderstorms,Rain,Fog                     100.080000

# %%
# Q12: Min/Max by weather condition
print("\n12a. Minimum values by weather condition:")
display(weather_df.groupby('Weather_Condition').min(numeric_only=True))
print("\n12b. Maximum values by weather condition:")
display(weather_df.groupby('Weather_Condition').max(numeric_only=True))
# Out:
# 12a. Minimum values by weather condition:
#                                          Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                     -23.3             -28.5
# Cloudy                                    -21.4             -26.8
# Drizzle                                     1.1              -0.2
# Drizzle,Fog                                 0.0              -1.6
# Drizzle,Ice Pellets,Fog                     0.4              -0.7
# Drizzle,Snow                                0.9               0.1
# Drizzle,Snow,Fog                            0.3              -0.1
# Fog                                       -16.0             -17.2
# Freezing Drizzle                           -9.0             -12.2
# Freezing Drizzle,Fog                       -6.4              -9.0
# Freezing Drizzle,Haze                      -5.8              -8.3
# Freezing Drizzle,Snow                      -8.3             -10.4
# Freezing Fog                              -19.0             -22.9
# Freezing Rain                              -6.5              -9.0
# Freezing Rain,Fog                          -6.1              -8.7
# Freezing Rain,Haze                         -4.9              -7.5
# Freezing Rain,Ice Pellets,Fog              -2.6              -3.7
# Freezing Rain,Snow Grains                  -5.0              -7.3
# Haze                                      -11.5             -16.0
# Mainly Clear                              -22.8             -28.0
# Moderate Rain,Fog                           1.7               0.8
# Moderate Snow                              -6.3              -7.6
# Moderate Snow,Blowing Snow                 -5.5              -6.6
# Mostly Cloudy                             -23.2             -28.5
# Rain                                        0.3              -5.7
# Rain Showers                                1.6              -7.2
# Rain Showers,Fog                           12.8              12.1
# Rain Showers,Snow Showers                   2.1              -1.8
# Rain,Fog                                    0.0              -1.2
# Rain,Haze                                   4.0               1.0
# Rain,Ice Pellets                            0.6              -0.6
# Rain,Snow                                   0.6              -1.7
# Rain,Snow Grains                            1.9              -2.1
# Rain,Snow,Fog                               0.8               0.3
# Rain,Snow,Ice Pellets                       0.9              -0.7
# Snow                                      -16.7             -24.6
# Snow Pellets                                0.7              -6.4
# Snow Showers                              -13.3             -19.3
# Snow Showers,Fog                          -11.3             -12.7
# Snow,Blowing Snow                         -12.0             -16.2
# Snow,Fog                                  -10.1             -12.0
# Snow,Haze                                  -4.3              -7.2
# Snow,Ice Pellets                           -4.3              -5.9
# Thunderstorms                              21.6              19.4
# Thunderstorms,Heavy Rain Showers           10.9               9.0
# Thunderstorms,Moderate Rain Showers,Fog    19.6              18.5
# Thunderstorms,Rain                         19.4              18.2
# Thunderstorms,Rain Showers                 11.0               7.0
# Thunderstorms,Rain Showers,Fog             19.5              16.1
# Thunderstorms,Rain,Fog                     20.6              18.6
#
#                                          Relative_Humidity_pct  \
# Weather_Condition
# Clear                                                       20
# Cloudy                                                      18
# Drizzle                                                     74
# Drizzle,Fog                                                 85
# Drizzle,Ice Pellets,Fog                                     92
# Drizzle,Snow                                                92
# Drizzle,Snow,Fog                                            92
# Fog                                                         80
# Freezing Drizzle                                            78
# Freezing Drizzle,Fog                                        82
# Freezing Drizzle,Haze                                       81
# Freezing Drizzle,Snow                                       79
# Freezing Fog                                                71
# Freezing Rain                                               81
# Freezing Rain,Fog                                           82
# Freezing Rain,Haze                                          82
# Freezing Rain,Ice Pellets,Fog                               92
# Freezing Rain,Snow Grains                                   84
# Haze                                                        68
# Mainly Clear                                                20
# Moderate Rain,Fog                                           94
# Moderate Snow                                               83
# Moderate Snow,Blowing Snow                                  92
# Mostly Cloudy                                               18
# Rain                                                        40
# Rain Showers                                                37
# Rain Showers,Fog                                            96
# Rain Showers,Snow Showers                                   75
# Rain,Fog                                                    83
# Rain,Haze                                                   81
# Rain,Ice Pellets                                            92
# Rain,Snow                                                   81
# Rain,Snow Grains                                            75
# Rain,Snow,Fog                                               96
# Rain,Snow,Ice Pellets                                       88
# Snow                                                        41
# Snow Pellets                                                59
# Snow Showers                                                52
# Snow Showers,Fog                                            89
# Snow,Blowing Snow                                           70
# Snow,Fog                                                    77
# Snow,Haze                                                   80
# Snow,Ice Pellets                                            76
# Thunderstorms                                               67
# Thunderstorms,Heavy Rain Showers                            88
# Thunderstorms,Moderate Rain Showers,Fog                     93
# Thunderstorms,Rain                                          83
# Thunderstorms,Rain Showers                                  68
# Thunderstorms,Rain Showers,Fog                              80
# Thunderstorms,Rain,Fog                                      88
#
#                                          Wind_Speed_kmh  Visibility_km  \
# Weather_Condition
# Clear                                                 0           11.3
# Cloudy                                                0           11.3
# Drizzle                                               0            6.4
# Drizzle,Fog                                           0            1.0
# Drizzle,Ice Pellets,Fog                              20            4.0
# Drizzle,Snow                                          9            9.7
# Drizzle,Snow,Fog                                      7            2.4
# Fog                                                   0            0.2
# Freezing Drizzle                                      6            4.8
# Freezing Drizzle,Fog                                  6            3.6
# Freezing Drizzle,Haze                                 9            2.0
# Freezing Drizzle,Snow                                 6            2.4
# Freezing Fog                                          0            0.2
# Freezing Rain                                         7            2.8
# Freezing Rain,Fog                                     7            2.8
# Freezing Rain,Haze                                    6            2.0
# Freezing Rain,Ice Pellets,Fog                        28            8.0
# Freezing Rain,Snow Grains                            32            4.8
# Haze                                                  0            4.8
# Mainly Clear                                          0           12.9
# Moderate Rain,Fog                                    17            6.4
# Moderate Snow                                        26            0.6
# Moderate Snow,Blowing Snow                           39            0.6
# Mostly Cloudy                                         0           11.3
# Rain                                                  0            4.0
# Rain Showers                                          0            6.4
# Rain Showers,Fog                                     13            6.4
# Rain Showers,Snow Showers                            17           19.3
# Rain,Fog                                              0            2.0
# Rain,Haze                                             7            4.0
# Rain,Ice Pellets                                     24            9.7
# Rain,Snow                                            13            2.4
# Rain,Snow Grains                                     26           25.0
# Rain,Snow,Fog                                         9            6.4
# Rain,Snow,Ice Pellets                                17            4.8
# Snow                                                  0            1.0
# Snow Pellets                                         35            2.4
# Snow Showers                                          0            2.4
# Snow Showers,Fog                                      7            4.0
# Snow,Blowing Snow                                    24            0.6
# Snow,Fog                                              4            1.2
# Snow,Haze                                             0            4.0
# Snow,Ice Pellets                                     19            2.8
# Thunderstorms                                         0           24.1
# Thunderstorms,Heavy Rain Showers                      9            2.4
# Thunderstorms,Moderate Rain Showers,Fog              15            3.2
# Thunderstorms,Rain                                    4           16.1
# Thunderstorms,Rain Showers                            7            6.4
# Thunderstorms,Rain Showers,Fog                        7            9.7
# Thunderstorms,Rain,Fog                               19            4.8
#
#                                          Pressure_kPa
# Weather_Condition
# Clear                                           99.52
# Cloudy                                          98.39
# Drizzle                                         97.84
# Drizzle,Fog                                     98.65
# Drizzle,Ice Pellets,Fog                        100.79
# Drizzle,Snow                                   100.63
# Drizzle,Snow,Fog                                97.79
# Fog                                             98.31
# Freezing Drizzle                                98.44
# Freezing Drizzle,Fog                            98.74
# Freezing Drizzle,Haze                          100.28
# Freezing Drizzle,Snow                           99.19
# Freezing Fog                                   101.97
# Freezing Rain                                   98.22
# Freezing Rain,Fog                               98.32
# Freezing Rain,Haze                             100.34
# Freezing Rain,Ice Pellets,Fog                  100.95
# Freezing Rain,Snow Grains                       98.56
# Haze                                           100.35
# Mainly Clear                                    98.67
# Moderate Rain,Fog                               99.98
# Moderate Snow                                   99.88
# Moderate Snow,Blowing Snow                     100.50
# Mostly Cloudy                                   98.36
# Rain                                            97.52
# Rain Showers                                    98.51
# Rain Showers,Fog                                99.83
# Rain Showers,Snow Showers                      101.09
# Rain,Fog                                        98.61
# Rain,Haze                                      100.50
# Rain,Ice Pellets                               100.12
# Rain,Snow                                       98.18
# Rain,Snow Grains                               100.60
# Rain,Snow,Fog                                  100.73
# Rain,Snow,Ice Pellets                           99.85
# Snow                                            97.75
# Snow Pellets                                    99.70
# Snow Showers                                    99.49
# Snow Showers,Fog                               100.63
# Snow,Blowing Snow                               98.11
# Snow,Fog                                        99.38
# Snow,Haze                                      100.61
# Snow,Ice Pellets                                99.40
# Thunderstorms                                   99.84
# Thunderstorms,Heavy Rain Showers               100.26
# Thunderstorms,Moderate Rain Showers,Fog        100.01
# Thunderstorms,Rain                             100.19
# Thunderstorms,Rain Showers                      99.65
# Thunderstorms,Rain Showers,Fog                  99.71
# Thunderstorms,Rain,Fog                         100.08
# 12b. Maximum values by weather condition:
#                                          Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                      32.8              20.4
# Cloudy                                     30.5              22.6
# Drizzle                                    18.8              17.7
# Drizzle,Fog                                19.9              19.1
# Drizzle,Ice Pellets,Fog                     0.4              -0.7
# Drizzle,Snow                                1.2               0.2
# Drizzle,Snow,Fog                            1.1               0.6
# Fog                                        20.8              19.6
# Freezing Drizzle                           -2.3              -3.3
# Freezing Drizzle,Fog                       -0.3              -2.3
# Freezing Drizzle,Haze                      -5.0              -7.7
# Freezing Drizzle,Snow                      -3.3              -4.6
# Freezing Fog                               -0.1              -0.3
# Freezing Rain                               0.3              -1.7
# Freezing Rain,Fog                           0.1              -0.9
# Freezing Rain,Haze                         -4.9              -7.4
# Freezing Rain,Ice Pellets,Fog              -2.6              -3.7
# Freezing Rain,Snow Grains                  -5.0              -7.3
# Haze                                       14.1              11.1
# Mainly Clear                               33.0              21.2
# Moderate Rain,Fog                           1.7               0.8
# Moderate Snow                              -4.9              -6.7
# Moderate Snow,Blowing Snow                 -5.4              -6.4
# Mostly Cloudy                              32.4              24.4
# Rain                                       22.8              20.4
# Rain Showers                               26.4              23.0
# Rain Showers,Fog                           12.8              12.1
# Rain Showers,Snow Showers                   2.2              -1.2
# Rain,Fog                                   21.7              19.5
# Rain,Haze                                   5.5               2.9
# Rain,Ice Pellets                            0.6              -0.6
# Rain,Snow                                   1.7               0.5
# Rain,Snow Grains                            1.9              -2.1
# Rain,Snow,Fog                               0.8               0.3
# Rain,Snow,Ice Pellets                       1.3               0.1
# Snow                                        3.7               0.3
# Snow Pellets                                0.7              -6.4
# Snow Showers                                2.9              -0.7
# Snow Showers,Fog                          -10.0             -11.1
# Snow,Blowing Snow                          -1.4              -2.9
# Snow,Fog                                    1.1               0.8
# Snow,Haze                                  -3.6              -6.4
# Snow,Ice Pellets                            0.8              -1.7
# Thunderstorms                              26.7              20.1
# Thunderstorms,Heavy Rain Showers           10.9               9.0
# Thunderstorms,Moderate Rain Showers,Fog    19.6              18.5
# Thunderstorms,Rain                         21.3              19.1
# Thunderstorms,Rain Showers                 25.5              23.1
# Thunderstorms,Rain Showers,Fog             22.9              21.3
# Thunderstorms,Rain,Fog                     20.6              18.6
#
#                                          Relative_Humidity_pct  \
# Weather_Condition
# Clear                                                       99
# Cloudy                                                      99
# Drizzle                                                     96
# Drizzle,Fog                                                100
# Drizzle,Ice Pellets,Fog                                     92
# Drizzle,Snow                                                95
# Drizzle,Snow,Fog                                            98
# Fog                                                        100
# Freezing Drizzle                                            93
# Freezing Drizzle,Fog                                        94
# Freezing Drizzle,Haze                                       83
# Freezing Drizzle,Snow                                       94
# Freezing Fog                                                99
# Freezing Rain                                               92
# Freezing Rain,Fog                                           93
# Freezing Rain,Haze                                          83
# Freezing Rain,Ice Pellets,Fog                               92
# Freezing Rain,Snow Grains                                   84
# Haze                                                        86
# Mainly Clear                                                99
# Moderate Rain,Fog                                           94
# Moderate Snow                                               93
# Moderate Snow,Blowing Snow                                  93
# Mostly Cloudy                                              100
# Rain                                                        99
# Rain Showers                                                97
# Rain Showers,Fog                                            96
# Rain Showers,Snow Showers                                   78
# Rain,Fog                                                   100
# Rain,Haze                                                   86
# Rain,Ice Pellets                                            92
# Rain,Snow                                                   94
# Rain,Snow Grains                                            75
# Rain,Snow,Fog                                               96
# Rain,Snow,Ice Pellets                                       94
# Snow                                                        96
# Snow Pellets                                                59
# Snow Showers                                                94
# Snow Showers,Fog                                            92
# Snow,Blowing Snow                                           91
# Snow,Fog                                                    99
# Snow,Haze                                                   81
# Snow,Ice Pellets                                            92
# Thunderstorms                                               87
# Thunderstorms,Heavy Rain Showers                            88
# Thunderstorms,Moderate Rain Showers,Fog                     93
# Thunderstorms,Rain                                          93
# Thunderstorms,Rain Showers                                  98
# Thunderstorms,Rain Showers,Fog                              91
# Thunderstorms,Rain,Fog                                      88
#
#                                          Wind_Speed_kmh  Visibility_km  \
# Weather_Condition
# Clear                                                33           48.3
# Cloudy                                               54           48.3
# Drizzle                                              30           25.0
# Drizzle,Fog                                          28            9.7
# Drizzle,Ice Pellets,Fog                              20            4.0
# Drizzle,Snow                                         19           11.3
# Drizzle,Snow,Fog                                     32            9.7
# Fog                                                  22            9.7
# Freezing Drizzle                                     26           12.9
# Freezing Drizzle,Fog                                 33            8.0
# Freezing Drizzle,Haze                                11            4.0
# Freezing Drizzle,Snow                                24           12.9
# Freezing Fog                                          9            0.8
# Freezing Rain                                        28           16.1
# Freezing Rain,Fog                                    26            9.7
# Freezing Rain,Haze                                    9            2.8
# Freezing Rain,Ice Pellets,Fog                        28            8.0
# Freezing Rain,Snow Grains                            32            4.8
# Haze                                                 17            9.7
# Mainly Clear                                         63           48.3
# Moderate Rain,Fog                                    17            6.4
# Moderate Snow                                        39            0.8
# Moderate Snow,Blowing Snow                           41            0.6
# Mostly Cloudy                                        83           48.3
# Rain                                                 52           48.3
# Rain Showers                                         41           48.3
# Rain Showers,Fog                                     13            6.4
# Rain Showers,Snow Showers                            28           24.1
# Rain,Fog                                             46            9.7
# Rain,Haze                                            17            9.7
# Rain,Ice Pellets                                     24            9.7
# Rain,Snow                                            52           25.0
# Rain,Snow Grains                                     26           25.0
# Rain,Snow,Fog                                         9            6.4
# Rain,Snow,Ice Pellets                                28            6.4
# Snow                                                 57           25.0
# Snow Pellets                                         35            2.4
# Snow Showers                                         37           48.3
# Snow Showers,Fog                                     22            9.7
# Snow,Blowing Snow                                    48            9.7
# Snow,Fog                                             35            9.7
# Snow,Haze                                            15            6.4
# Snow,Ice Pellets                                     33           11.3
# Thunderstorms                                        15           25.0
# Thunderstorms,Heavy Rain Showers                      9            2.4
# Thunderstorms,Moderate Rain Showers,Fog              15            3.2
# Thunderstorms,Rain                                   30           24.1
# Thunderstorms,Rain Showers                           32           25.0
# Thunderstorms,Rain Showers,Fog                       35            9.7
# Thunderstorms,Rain,Fog                               19            4.8
#
#                                          Pressure_kPa
# Weather_Condition
# Clear                                          103.63
# Cloudy                                         103.65
# Drizzle                                        101.56
# Drizzle,Fog                                    102.07
# Drizzle,Ice Pellets,Fog                        100.79
# Drizzle,Snow                                   101.15
# Drizzle,Snow,Fog                               100.15
# Fog                                            103.04
# Freezing Drizzle                               101.02
# Freezing Drizzle,Fog                           101.27
# Freezing Drizzle,Haze                          100.36
# Freezing Drizzle,Snow                          101.18
# Freezing Fog                                   102.85
# Freezing Rain                                  101.00
# Freezing Rain,Fog                              101.01
# Freezing Rain,Haze                             100.41
# Freezing Rain,Ice Pellets,Fog                  100.95
# Freezing Rain,Snow Grains                       98.56
# Haze                                           102.97
# Mainly Clear                                   103.59
# Moderate Rain,Fog                               99.98
# Moderate Snow                                  100.67
# Moderate Snow,Blowing Snow                     100.64
# Mostly Cloudy                                  103.65
# Rain                                           102.26
# Rain Showers                                   102.31
# Rain Showers,Fog                                99.83
# Rain Showers,Snow Showers                      101.11
# Rain,Fog                                       101.77
# Rain,Haze                                      100.61
# Rain,Ice Pellets                               100.12
# Rain,Snow                                      101.07
# Rain,Snow Grains                               100.60
# Rain,Snow,Fog                                  100.73
# Rain,Snow,Ice Pellets                          100.47
# Snow                                           102.73
# Snow Pellets                                    99.70
# Snow Showers                                   102.50
# Snow Showers,Fog                               102.52
# Snow,Blowing Snow                              100.62
# Snow,Fog                                       102.07
# Snow,Haze                                      100.99
# Snow,Ice Pellets                               100.96
# Thunderstorms                                  100.62
# Thunderstorms,Heavy Rain Showers               100.26
# Thunderstorms,Moderate Rain Showers,Fog        100.01
# Thunderstorms,Rain                             100.83
# Thunderstorms,Rain Showers                     101.06
# Thunderstorms,Rain Showers,Fog                 100.64
# Thunderstorms,Rain,Fog                         100.08

# %%
# Q13: Fog records
fog_records = weather_df[weather_df['Weather_Condition'] == 'Fog']
print(f"\n13. Fog records found: {fog_records.shape[0]}")
# Out:
# 13. Fog records found: 150

# %%
# Q14: Clear or good visibility
clear_or_good_vis = weather_df[(weather_df['Weather_Condition'] == 'Clear') | 
                          (weather_df['Visibility_km'] > 40)]
print("\n14. Records with clear weather OR visibility >40 km:")
display(clear_or_good_vis.tail(50))
# Out:
# 14. Records with clear weather OR visibility >40 km:
#              Date/Time  Temp_C  Dew Point Temp_C  Relative_Humidity_pct  \
# 8387  12/15/2012 11:00    -9.3             -14.9                     64
# 8388  12/15/2012 12:00    -9.1             -15.1                     62
# 8389  12/15/2012 13:00    -8.4             -14.7                     60
# 8390  12/15/2012 14:00    -8.0             -14.2                     61
# 8391  12/15/2012 15:00    -7.8             -13.7                     63
# 8392  12/15/2012 16:00    -8.5             -14.8                     60
# 8394  12/15/2012 18:00    -9.1             -15.1                     62
# 8396  12/15/2012 20:00    -8.7             -15.1                     60
# 8408   12/16/2012 8:00    -9.5             -14.8                     65
# 8599   12/24/2012 7:00   -11.1             -13.9                     80
# 8600   12/24/2012 8:00   -11.0             -13.9                     79
# 8601   12/24/2012 9:00   -10.5             -13.7                     77
# 8602  12/24/2012 10:00    -9.9             -13.4                     76
# 8603  12/24/2012 11:00    -9.0             -13.7                     69
# 8604  12/24/2012 12:00    -7.9             -13.3                     65
# 8605  12/24/2012 13:00    -7.6             -13.1                     65
# 8606  12/24/2012 14:00    -7.8             -13.7                     63
# 8607  12/24/2012 15:00    -7.5             -13.3                     63
# 8610  12/24/2012 18:00   -10.4             -13.8                     76
# 8630  12/25/2012 14:00    -7.7             -14.1                     60
# 8631  12/25/2012 15:00    -7.1             -13.7                     59
# 8632  12/25/2012 16:00    -7.5             -13.9                     60
# 8633  12/25/2012 17:00    -8.3             -13.4                     67
# 8637  12/25/2012 21:00    -9.7             -12.5                     80
# 8638  12/25/2012 22:00   -10.9             -13.2                     83
# 8639  12/25/2012 23:00   -10.4             -12.7                     83
# 8640   12/26/2012 0:00   -11.8             -13.5                     87
# 8641   12/26/2012 1:00   -11.2             -12.9                     87
# 8642   12/26/2012 2:00   -12.7             -14.4                     87
# 8643   12/26/2012 3:00   -14.2             -15.8                     88
# 8644   12/26/2012 4:00   -13.1             -14.7                     88
# 8645   12/26/2012 5:00   -12.7             -14.1                     89
# 8646   12/26/2012 6:00   -13.4             -14.8                     89
# 8651  12/26/2012 11:00   -11.3             -14.5                     77
# 8652  12/26/2012 12:00   -10.6             -14.3                     74
# 8698  12/28/2012 10:00    -6.1              -8.6                     82
# 8699  12/28/2012 11:00    -6.2              -8.8                     82
# 8700  12/28/2012 12:00    -7.2              -9.9                     81
# 8701  12/28/2012 13:00    -6.8              -9.8                     79
# 8702  12/28/2012 14:00    -6.5              -9.9                     77
# 8703  12/28/2012 15:00    -6.8             -10.3                     76
# 8704  12/28/2012 16:00    -7.7             -11.0                     77
# 8713   12/29/2012 1:00   -11.9             -13.6                     87
# 8714   12/29/2012 2:00   -11.8             -13.1                     90
# 8748  12/30/2012 12:00   -12.2             -15.7                     75
# 8749  12/30/2012 13:00   -12.4             -16.2                     73
# 8750  12/30/2012 14:00   -11.8             -16.1                     70
# 8751  12/30/2012 15:00   -11.3             -15.6                     70
# 8752  12/30/2012 16:00   -11.4             -15.5                     72
# 8756  12/30/2012 20:00   -13.8             -16.5                     80
#
#       Wind_Speed_kmh  Visibility_km  Pressure_kPa Weather_Condition
# 8387              19           48.3        102.74      Mainly Clear
# 8388              19           48.3        102.71      Mainly Clear
# 8389              19           48.3        102.64             Clear
# 8390              13           48.3        102.59      Mainly Clear
# 8391              15           48.3        102.55      Mainly Clear
# 8392              20           48.3        102.54      Mainly Clear
# 8394              17           25.0        102.54             Clear
# 8396              20           25.0        102.50             Clear
# 8408              32           48.3        101.85            Cloudy
# 8599              15           25.0        101.23             Clear
# 8600              13           25.0        101.32             Clear
# 8601              13           24.1        101.41             Clear
# 8602              11           48.3        101.45      Mainly Clear
# 8603              11           48.3        101.44      Mainly Clear
# 8604               9           48.3        101.43      Mainly Clear
# 8605              15           48.3        101.45      Mainly Clear
# 8606              15           48.3        101.46      Mainly Clear
# 8607              13           48.3        101.49      Mainly Clear
# 8610               9           25.0        101.45             Clear
# 8630               6           48.3        101.95      Mainly Clear
# 8631              17           48.3        101.98             Clear
# 8632              11           48.3        102.03             Clear
# 8633              13           25.0        102.10             Clear
# 8637               4           25.0        102.28             Clear
# 8638               4           25.0        102.34             Clear
# 8639              11           25.0        102.45             Clear
# 8640               4           25.0        102.41             Clear
# 8641               6           25.0        102.42             Clear
# 8642               4           25.0        102.45             Clear
# 8643               6           25.0        102.52             Clear
# 8644               6           25.0        102.55             Clear
# 8645               4           25.0        102.48             Clear
# 8646               4           25.0        102.47             Clear
# 8651              20           48.3        102.50      Mainly Clear
# 8652              20           48.3        102.36      Mainly Clear
# 8698              19           24.1        101.27             Clear
# 8699              24           48.3        101.24      Mainly Clear
# 8700              24           48.3        101.22      Mainly Clear
# 8701              20           48.3        101.17      Mainly Clear
# 8702              22           48.3        101.17      Mainly Clear
# 8703              24           48.3        101.22      Mainly Clear
# 8704              30           48.3        101.25      Mainly Clear
# 8713              11           25.0        101.31             Clear
# 8714              13           25.0        101.33             Clear
# 8748              26           48.3        100.91     Mostly Cloudy
# 8749              37           48.3        100.92     Mostly Cloudy
# 8750              37           48.3        100.96      Mainly Clear
# 8751              32           48.3        101.05      Mainly Clear
# 8752              26           48.3        101.15      Mainly Clear
# 8756              24           25.0        101.52             Clear

# %%
# Q15: Complex condition
complex_condition = weather_df[((weather_df['Weather_Condition'] == 'Clear') & 
                          (weather_df['Relative_Humidity_pct'] > 50)) | 
                         (weather_df['Visibility_km'] > 40)]
print("\n15. Records meeting complex condition:")
# Out:
# 15. Records meeting complex condition:
